# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/ratings.csv")
data
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
data.shape
# Out:
# (100836, 4)

# %%
data.columns = ["userId","movieId", "grade", "moment"]

# %%
data.head()
# Out:
#    userId  movieId  grade     moment
# 0       1        1    4.0  964982703
# 1       1        3    4.0  964981247
# 2       1        6    4.0  964982224
# 3       1       47    5.0  964983815
# 4       1       50    5.0  964982931

# %%
data["grade"].unique()
#retorna os valores unicos
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
data["grade"].value_counts()
# Out:
# grade
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
data["grade"].mean()
#retorna a média das notas
# Out:
# np.float64(3.501556983616962)

# %%
data["grade"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["grade"].median()
# Out:
# 3.5

# %%
average = data["grade"].mean()
median = data["grade"].median()
print(f"Mediana é {median}")
print(f"Media é {average}")
# Out:
# Mediana é 3.5
# Media é 3.501556983616962

# %%
data["grade"].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: grade, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(data["grade"])
# Out:
# <Axes: ylabel='grade'>

# %%
movies = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/movies.csv")
movies.columns = ["movieId","title","genres"]

# %%
data.head()
# Out:
#    userId  movieId  grade     moment
# 0       1        1    4.0  964982703
# 1       1        3    4.0  964981247
# 2       1        6    4.0  964982224
# 3       1       47    5.0  964983815
# 4       1       50    5.0  964982931

# %%
data.query("movieId ==1")
data.query("movieId ==1").mean()
# Out:
# userId     3.065302e+02
# movieId    1.000000e+00
# grade      3.920930e+00
# moment     1.129835e+09
# dtype: float64

# %%
data.query("movieId ==1")["grade"].mean()
# Out:
# np.float64(3.9209302325581397)

# %%
data.query("movieId ==2")["grade"].mean()
# Out:
# np.float64(3.4318181818181817)

# %%
data.groupby("movieId")

# %%
data.groupby("movieId").mean()
# Out:
#              userId     grade        moment
# movieId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
movieAverage = data.groupby("movieId")["grade"].mean()
movieAverage.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: grade, dtype: float64

# %%
movieAverage.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(movieAverage)
# Out:
# <Axes: ylabel='grade'>

# %%
movieAverage.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: grade, dtype: float64

# %%
import matplotlib.pyplot as plt
sns.displot(movieAverage, kde=True)
plt.title("Histograma média de notas dos filmes agrupados por id")
# Out:
# Text(0.5, 1.0, 'Histograma média de notas dos filmes agrupados por id')
